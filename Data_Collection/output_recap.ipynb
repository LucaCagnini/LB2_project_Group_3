# %% [markdown]
# ### Short script to visualize results

# %%
import pandas as pd

negative_set = pd.read_csv("negative_dataset.tsv", sep="\t")
positive_set = pd.read_csv("positive_dataset.tsv", sep="\t")

print(len(positive_set), "All positives. ")
print(len(negative_set), "All negatives. ")
print(len(negative_set[negative_set["HelixDomain"] == True]), "Negatives with transmembrane within the first 90 residues. ")
# Out:
# 2932 All positives.
# 20615 All negatives.
# 1384 Negatives with transmembrane within the first 90 residues.

# %%
cluster_neg_set = pd.read_csv("~/lab2_project/LB2_project_Group_3/Data_Collection/neg_cluster/negative_representative_data.tsv" , sep="\t")
cluster_pos_set = pd.read_csv("~/lab2_project/LB2_project_Group_3/Data_Collection/pos_cluster/positive_representative_data.tsv" , sep="\t")

print(len(cluster_pos_set) , "Non-redundant positives. ")
print(len(cluster_neg_set) , "Non-redundant negatives. ")
print(len(cluster_neg_set[cluster_neg_set["HelixDomain"] == True]), "Non-redundant negatives with transmembrane within the first 90 residues. ")
# Out:
# 1093 Non-redundant positives.
# 8934 Non-redundant negatives.
# 636 Non-redundant negatives with transmembrane within the first 90 residues.
