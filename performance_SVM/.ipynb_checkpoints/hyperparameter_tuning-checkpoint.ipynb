# %%
import pandas as pd
import numpy as np
from importnb import Notebook
import sys, io
import matplotlib
import glob, os
# add the folder vonheijine that contains our vonheijine functions
sys.path.append('../Feature_Selection/')
# avoid to print useless things when importing another notebook
matplotlib.use('Agg')  # blocca la visualizzazione grafica
old_stdout = sys.stdout
sys.stdout = io.StringIO()  

with Notebook():
    import custom_features, feauture_selection
sys.stdout = old_stdout

#remove temporary files created by feature_selection
for f in glob.glob("*_features_*.npz"):
    os.remove(f)

# %%
print(feauture_selection.features_to_use)
# Out:
# ['VhonHeijne', 'C', 'tm_tendency_max', 'chou_fasman_h_mean', 'max_miyazawa_mean', 'D', 'T', 'R', 'chou_fasma_b_max', 'N', 'flexibility_max', 'punta_max', 'bulkiness_mean', 'M', 'argos_max']

# %%
def update_vonheijne(sets, matrix): 
    seq_features=[]
    for seq in sets:
        seq=seq.replace("X" , "")
        seq=seq.replace("U" , "C")
        vonhejine=custom_features.vonheijne_feature(matrix, seq) #get the von heijne feature for that sequence
        seq_features.append(vonhejine)
    hejine_col = np.array(seq_features) #transform the list that contains all the features in an array
    return hejine_col

# %%
#Load the npz files of training, testing and validation sets for each iteration
# load training
# 5th iteration was: validation set 1 , training set 2,3,4 , testing set 5
loaded_data_train = np.load('../Feature_Selection/training_features_5.npz')
x_train = loaded_data_train['matrix']
y_train = loaded_data_train['target']

# load test
loaded_data_test = np.load('../Feature_Selection/testing_features_5.npz')
x_test = loaded_data_test['matrix']
y_test = loaded_data_test['target']

# load validation
loaded_data_validation = np.load('../Feature_Selection/validation_features_5.npz')
x_validation = loaded_data_validation['matrix']
y_validation = loaded_data_validation['target']

#concatenate the matrices in the correct order
x_training_conc = np.concatenate((x_validation, x_train , x_test), axis=0) #order is maintained: 1,2,3,4,5
y_training_conc = np.concatenate((y_validation , y_train, y_test), axis=0)

# %%
#Load the benchmark set and encode it
dataset = pd.read_csv("../Data_Preparation/train_bench.tsv", sep = "\t")
benchmark=dataset.query("Set=='Benchmark'")
training= pd.concat([dataset.query("Set=='2'"), dataset.query(" Set=='3' or Set=='4' or Set=='5' "), dataset.query("Set=='1'")],axis=0,ignore_index=True)
matrix_training=custom_features.get_pswm(training , 13 , 2)
#replace the old VonHejine feature with the new VonHejine basing on the updated PSWM
x_training_conc[:, 17] = update_vonheijne(training["Sequence"], matrix_training)
feature_set_benchmark , feature_order_training = custom_features.get_all_features(benchmark["Sequence"] , matrix_training, 15 )
vector_neg_pos = benchmark["Class"]
vector_proper = vector_neg_pos.map({"Positive": 1, "Negative": 0})
target_benchmark_vector = vector_proper.to_numpy()

# %%
index=[]
for feature in feature_order_training:
    if feature not in feauture_selection.features_to_use:
        index.append(feature_order_training.index(feature))
x_training_conc=np.delete(x_training_conc, index, axis=1)
x_benchmark=np.delete(feature_set_benchmark, index, axis=1)
np.savez('benchmark_features.npz', matrix=x_benchmark, target=target_benchmark_vector)
np.savez('training_features.npz', matrix=x_training_conc, target=y_training_conc)

# %% [markdown]
# ## Hyperparameter Tuning

# %%
import numpy as np
from sklearn.metrics import matthews_corrcoef
#! pip install scikit-optimize
from skopt import BayesSearchCV
from skopt.space import Real, Integer, Categorical
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import PredefinedSplit
from sklearn.svm import SVC
from sklearn.metrics import matthews_corrcoef , confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#create the pipeline
pipeline = Pipeline([("scaler" , StandardScaler()) , ("svm" , SVC(cache_size=1500))])

# %%
# parameter search using BayesSearchCV

# search space for rbf kernel
search_space = {
        "svm__kernel": Categorical(["rbf"]),
        "svm__C": Real(0.01, 100, prior="log-uniform"),                
        "svm__gamma": Real(0.01, 100, prior="log-uniform"), 
    }

# %%
#set up the BayesSearch
bayes = BayesSearchCV(
    estimator=pipeline,
    search_spaces=search_space,
    scoring="matthews_corrcoef",   
    n_jobs=-1,
    refit=False,                 
    random_state=42,
    verbose=2,
    cv=5,
    n_iter=60
)
bayes.fit(x_training_conc, y_training_conc)  # here we perform the bayes search

print("\n[Best parameters found:] ")
print(bayes.best_params_)
print(f"[Best MCC validation] {bayes.best_score_:.4f}")
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END svm__C=0.4369339947510315, svm__gamma=8.145222883402798, svm__kernel=rbf; total time=   2.3s
# [CV] END svm__C=22.364202820542708, svm__gamma=34.139810765573976, svm__kernel=rbf; total time=   3.6s
# [CV] END svm__C=22.364202820542708, svm__gamma=34.139810765573976, svm__kernel=rbf; total time=   3.5s
# [CV] END svm__C=0.6016307829589929, svm__gamma=47.30315267320388, svm__kernel=rbf; total time=   3.6s
# [CV] END svm__C=17.76576664980768, svm__gamma=0.04869521028037488, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=15.783879853890564, svm__gamma=0.5650888599199564, svm__kernel=rbf; total time=   2.8s
# [CV] END svm__C=8.632012725909878, svm__gamma=57.21092247217263, svm__kernel=rbf; total time=   3.9s
# [CV] END svm__C=2.9397976202716882, svm__gamma=12.631575298699973, svm__kernel=rbf; total time=   2.8s
# [CV] END svm__C=2.9397976202716882, svm__gamma=12.631575298699973, svm__kernel=rbf; total time=   2.5s
# [CV] END svm__C=1.491462267977867, svm__gamma=47.867076737948445, svm__kernel=rbf; total time=   3.8s
# [CV] END svm__C=66.36085077612337, svm__gamma=6.345791205561904, svm__kernel=rbf; total time=   2.6s
# [CV] END svm__C=66.36085077612337, svm__gamma=6.345791205561904, svm__kernel=rbf; total time=   2.1s
# [CV] END svm__C=0.010340016434251914, svm__gamma=18.67755735247498, svm__kernel=rbf; total time=   3.3s
# [CV] END ......svm__C=0.01, svm__gamma=0.01, svm__kernel=rbf; total time=   0.6s
# [CV] END svm__C=28.437651844525654, svm__gamma=0.05945439606657635, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=0.01, svm__gamma=0.05016319966446331, svm__kernel=rbf; total time=   0.5s
# [CV] END svm__C=0.01, svm__gamma=0.05016319966446331, svm__kernel=rbf; total time=   0.5s
# [CV] END svm__C=24.994573457390125, svm__gamma=0.031796310007014994, svm__kernel=rbf; total time=   0.3s
# [CV] END .....svm__C=100.0, svm__gamma=0.01, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=100.0, svm__gamma=0.01745169852565343, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=41.37577374489088, svm__gamma=0.01, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=14.196702314741737, svm__gamma=0.01, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=14.196702314741737, svm__gamma=0.01, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=11.205997141144886, svm__gamma=0.017481942702379436, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=19.69068581321337, svm__gamma=0.013837212966927137, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=19.69068581321337, svm__gamma=0.013837212966927137, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=4.49579953524872, svm__gamma=0.023999433969059847, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=4.49579953524872, svm__gamma=0.023999433969059847, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=4.120195761285078, svm__gamma=0.011854787606076991, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=5.6319809466552595, svm__gamma=0.01588869882949274, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=5.6319809466552595, svm__gamma=0.01588869882949274, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=2.292060492853348, svm__gamma=0.01, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=2.292060492853348, svm__gamma=0.01, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=1.8654162541232162, svm__gamma=0.0208065323584264, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=2.279313362037483, svm__gamma=0.04057350305918036, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=2.279313362037483, svm__gamma=0.04057350305918036, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=1.1342689801584394, svm__gamma=0.04282092006473865, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=1.7174059073344699, svm__gamma=0.07024942388356967, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=1.7174059073344699, svm__gamma=0.07024942388356967, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=0.7768759547394981, svm__gamma=0.01, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=0.8122997547924575, svm__gamma=0.020405337542693577, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=3.8886722307770305, svm__gamma=0.0571072840419735, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=3.8886722307770305, svm__gamma=0.0571072840419735, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=0.5862195614896641, svm__gamma=0.07218651123520496, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=0.44982107173462155, svm__gamma=0.03523019583841073, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=0.6990744030036357, svm__gamma=0.04102041456134992, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=0.6990744030036357, svm__gamma=0.04102041456134992, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=0.32028497407741835, svm__gamma=0.01, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=100.0, svm__gamma=0.06603558310808587, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=0.3840693605720742, svm__gamma=0.018758311036054555, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=2.877211378374452, svm__gamma=0.04032165797349227, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=2.877211378374452, svm__gamma=0.04032165797349227, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=0.23714408168534465, svm__gamma=0.04520996870943172, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=0.23041799980294717, svm__gamma=0.12874616984516155, svm__kernel=rbf; total time=   0.5s
# [CV] END svm__C=1.8321544911501937, svm__gamma=0.04620324081265835, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=1.7616420312157917, svm__gamma=0.0346590170349046, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=0.010772016221132049, svm__gamma=95.28674415547745, svm__kernel=rbf; total time=   3.4s
# [CV] END svm__C=2.3088625916470713, svm__gamma=0.05030678447015087, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=0.4539971097751994, svm__gamma=0.04079030467380409, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=0.4539971097751994, svm__gamma=0.04079030467380409, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=5.131322634959385, svm__gamma=0.03811221362653131, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=7.142791254540834, svm__gamma=0.01, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=7.142791254540834, svm__gamma=0.01, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=5.780472848269825, svm__gamma=0.01, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=5.780472848269825, svm__gamma=0.01, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=1.0653267802828759, svm__gamma=0.0491793065104212, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=1.0653267802828759, svm__gamma=0.0491793065104212, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=2.419441404288762, svm__gamma=0.029881787848739964, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=2.419441404288762, svm__gamma=0.029881787848739964, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=0.19550155037694372, svm__gamma=0.021990532153535393, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=0.19550155037694372, svm__gamma=0.021990532153535393, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=3.2162838219590335, svm__gamma=0.11395311045055523, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=1.2874769533320176, svm__gamma=0.14437006549409662, svm__kernel=rbf; total time=   0.5s
# [CV] END svm__C=0.31902017426443213, svm__gamma=0.028920910861933668, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=0.31902017426443213, svm__gamma=0.028920910861933668, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=1.0019470824591996, svm__gamma=0.03328563552158566, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=0.810488270527049, svm__gamma=0.037435306566266965, svm__kernel=rbf; total time=   0.3s
# [CV] END svm__C=0.810488270527049, svm__gamma=0.037435306566266965, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=91.84003898986639, svm__gamma=97.78635823362609, svm__kernel=rbf; total time=   3.0s
# [CV] END svm__C=0.8126850381913172, svm__gamma=0.03723968393346386, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=0.8126850381913172, svm__gamma=0.03723968393346386, svm__kernel=rbf; total time=   0.2s
# [CV] END svm__C=1.1185925735281854, svm__gamma=0.032504521954211316, svm__kernel=rbf; total time=   0.2sFitting 5 folds for each of 1 candidates, totalling 5 fits
#
# [Best parameters found:]
# OrderedDict({'svm__C': 2.279313362037483, 'svm__gamma': 0.04057350305918036, 'svm__kernel': 'rbf'})
# [Best MCC validation] 0.8569

# %%
#predict the benchmark set
pipeline.set_params(**bayes.best_params_).fit(x_training_conc, y_training_conc) #parameters of BayesSearchCV
bench_pred = pipeline.predict(x_benchmark)
#compute the mcc
mcc_bayes = matthews_corrcoef(target_benchmark_vector , bench_pred)
print(f"MCC on testing set (bayesian search): {mcc_bayes}")
# Out:
# MCC on testing set (bayesian search): 0.8143269690267844

# %%
conf_mat = confusion_matrix(target_benchmark_vector , bench_pred)
print(conf_mat)
sns.heatmap(
        conf_mat,
        annot=True,
        cmap="Blues",
        fmt="d",
        cbar=False,
        vmax = 200      
    )
plt.xlabel("Predicted")
plt.ylabel("Observed")  
plt.title("Confusion Matrix")  
plt.xticks(ticks=[0.5, 1.5], labels=["Negative", "Positive"])
plt.yticks(ticks=[0.5, 1.5], labels=["Negative", "Positive"], rotation=0)
plt.show()
# Out:
# [[1745   42]
#  [  32  187]]
