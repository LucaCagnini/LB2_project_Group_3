# %%
## import numpy as np
import pandas as pd
import numpy as np
from importnb import Notebook
import sys, io
import matplotlib
# add the folder vonheijine that contains our vonheijine functions
sys.path.append('../Feature_Selection/')
# avoid to print useless things when importing another notebook
matplotlib.use('Agg')  # blocca la visualizzazione grafica
old_stdout = sys.stdout
sys.stdout = io.StringIO()  

with Notebook():
    import custom_features, feauture_selection


sys.stdout = old_stdout
# Out:
# /mnt/c/Users/chari/OneDrive - Alma Mater Studiorum Università di Bologna/Scuola/Università/MAGISTRALE/GitHub/LB2_project_Group_3/performance_SVM/../Feature_Selection/feauture_selection.ipynb:608: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /mnt/c/Users/chari/OneDrive - Alma Mater Studiorum Università di Bologna/Scuola/Università/MAGISTRALE/GitHub/LB2_project_Group_3/performance_SVM/../Feature_Selection/feauture_selection.ipynb:647: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /mnt/c/Users/chari/OneDrive - Alma Mater Studiorum Università di Bologna/Scuola/Università/MAGISTRALE/GitHub/LB2_project_Group_3/performance_SVM/../Feature_Selection/feauture_selection.ipynb:608: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /mnt/c/Users/chari/OneDrive - Alma Mater Studiorum Università di Bologna/Scuola/Università/MAGISTRALE/GitHub/LB2_project_Group_3/performance_SVM/../Feature_Selection/feauture_selection.ipynb:647: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /mnt/c/Users/chari/OneDrive - Alma Mater Studiorum Università di Bologna/Scuola/Università/MAGISTRALE/GitHub/LB2_project_Group_3/performance_SVM/../Feature_Selection/feauture_selection.ipynb:608: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /mnt/c/Users/chari/OneDrive - Alma Mater Studiorum Università di Bologna/Scuola/Università/MAGISTRALE/GitHub/LB2_project_Group_3/performance_SVM/../Feature_Selection/feauture_selection.ipynb:647: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /mnt/c/Users/chari/OneDrive - Alma Mater Studiorum Università di Bologna/Scuola/Università/MAGISTRALE/GitHub/LB2_project_Group_3/performance_SVM/../Feature_Selection/feauture_selection.ipynb:608: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /mnt/c/Users/chari/OneDrive - Alma Mater Studiorum Università di Bologna/Scuola/Università/MAGISTRALE/GitHub/LB2_project_Group_3/performance_SVM/../Feature_Selection/feauture_selection.ipynb:647: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /mnt/c/Users/chari/OneDrive - Alma Mater Studiorum Università di Bologna/Scuola/Università/MAGISTRALE/GitHub/LB2_project_Group_3/performance_SVM/../Feature_Selection/feauture_selection.ipynb:608: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /mnt/c/Users/chari/OneDrive - Alma Mater Studiorum Università di Bologna/Scuola/Università/MAGISTRALE/GitHub/LB2_project_Group_3/performance_SVM/../Feature_Selection/feauture_selection.ipynb:647: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
print(feauture_selection.features_to_use)
# Out:
# ['VhonHeijne', 'tm_tendency_max', 'C', 'max_miyazawa_mean', 'chou_fasman_h_mean', 'flexibility_max', 'punta_max', 'flexibility_mean', 'basicity', 'tm_tendency_mean', 'R', 'miyazawa_mean', 'bulkiness_mean']

# %%
def update_vonheijne(sets, matrix): 
    seq_features=[]
    for seq in sets:
        seq=seq.replace("X" , "")
        seq=seq.replace("U" , "C")
        vonhejine=custom_features.vonheijne_feature(matrix, seq) #get the von heijne feature for that sequence
        seq_features.append(vonhejine)
    hejine_col = np.array(seq_features) #transform the list that contains all the features in an array
    return hejine_col

# %%
#Load the npz files of training, testing and validation sets for each iteration
# load training
loaded_data_train = np.load('../Feature_Selection/training_features_1.npz')
x_train = loaded_data_train['matrix']
y_train = loaded_data_train['target']


# load test
loaded_data_test = np.load('../Feature_Selection/testing_features_1.npz')
x_test = loaded_data_test['matrix']
y_test = loaded_data_test['target']

# load validation
loaded_data_validation = np.load('../Feature_Selection/validation_features_1.npz')
x_validation = loaded_data_validation['matrix']
y_validation = loaded_data_validation['target']

#concatenate the matrices in the correct order
x_training_conc = np.concatenate((x_test, x_train), axis=0) 
y_training_conc = np.concatenate((y_test, y_train), axis=0)

# np.savez('training_features.npz', matrix=x_training_conc, target=y_training_conc)
# np.savez('validation_features.npz', matrix=x_validation, target=y_validation)

# %%
#Load the benchmark set and encode it
dataset = pd.read_csv("../Data_Preparation/train_bench.tsv", sep = "\t")
benchmark=dataset.query("Set=='Benchmark'")
training=dataset.query("Set=='1' or Set=='3' or Set=='4' or Set== '5'")
validation=dataset.query("Set=='2'")
matrix_training=custom_features.get_pswm(training , 13 , 2)
#replace the old VonHejine feature with the new VonHejine basing on the update PSWM
x_training_conc[:, 17] = update_vonheijne(training["Sequence"], matrix_training)
x_validation[:, 17] = update_vonheijne(validation["Sequence"], matrix_training)
feature_set_benchmark , feature_order_training = custom_features.get_all_features(benchmark["Sequence"] , matrix_training, 15 )
vector_neg_pos = benchmark["Class"]
vector_proper = vector_neg_pos.map({"Positive": 1, "Negative": 0})
target_benchmark_vector = vector_proper.to_numpy()

# %%
index=[]
for feature in feature_order_training:
    if feature not in feauture_selection.features_to_use:
        index.append(feature_order_training.index(feature))
x_training_conc=np.delete(x_training_conc, index, axis=1)
x_validation=np.delete(x_validation, index, axis=1)
x_benchmark=np.delete(feature_set_benchmark, index, axis=1)
np.savez('benchmark_features.npz', matrix=x_benchmark, target=target_benchmark_vector)
np.savez('training_features.npz', matrix=x_training_conc, target=y_training_conc)
np.savez('validation_features.npz', matrix=x_validation, target=y_validation)

# %% [markdown]
# ## Hyperparameter Tuning

# %%
import numpy as np
from sklearn.metrics import matthews_corrcoef
#! pip install scikit-optimize
from skopt import BayesSearchCV
from sklearn.model_selection import GridSearchCV
from skopt.space import Real, Integer, Categorical
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import PredefinedSplit
from sklearn.svm import SVC
from sklearn.metrics import matthews_corrcoef , confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#create the pipeline
pipeline = Pipeline([("scaler" , StandardScaler()) , ("svm" , SVC())])

# %%
# parameter search using BayesSearchCV

# search spaces for rbf kernel and polynomial
search_spaces = [
    ({
        "svm__kernel": Categorical(["rbf"]),
        "svm__C": Real(0.01, 10, prior="log-uniform"),                
        "svm__gamma": Real(0.01, 10, prior="log-uniform"), 
    }, 40),
    ({
        "svm__kernel": Categorical(["poly"]),
        "svm__C": Real(0.01, 10, prior="log-uniform"),
        "svm__gamma": Real(0.01, 10, prior="log-uniform"),
        "svm__degree": Integer(2,4),
    }, 40),
]

# now we have to manually tell the BayesSearch function which datasets to use as training and validation
x_all = np.concatenate([x_training_conc, x_validation])
y_all = np.concatenate([y_training_conc, y_validation])

#we create arrays that map each training and testing example to -1 (training) or 0 (validatio)
test_fold = np.r_[
    -np.ones(len(x_training_conc), dtype=int),
     np.zeros(len(x_validation),   dtype=int)
]
#we create the predifined split
cv = PredefinedSplit(test_fold)

# %%
#set up the BayesSearch
bayes = BayesSearchCV(
    estimator=pipeline,
    search_spaces=search_spaces,
    scoring="matthews_corrcoef",   
    n_jobs=-1,
    #n_points=5 da provare
    refit=False,                 
    random_state=42,
    verbose=2, #proviamo a settarlo su 1
    cv=cv
)
bayes.fit(x_all, y_all)  # here we perform the bayes search

print("\n[Best parameters found:] ")
print(bayes.best_params_)
print(f"[Best MCC validation] {bayes.best_score_:.4f}")
# Out:
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# Fitting 1 folds for each of 1 candidates, totalling 1 fits
# [CV] END svm__C=3.2521088005944945, svm__gamma=4.466278825224283, svm__kernel=rbf; total time=   2.3s
# [CV] END svm__C=1.5925169151603527, svm__gamma=6.5782324054154415, svm__kernel=rbf; total time=   2.4s
# [CV] END svm__C=0.010253943538922507, svm__gamma=2.841123150877317, svm__kernel=rbf; total time=   1.7s
# [CV] END svm__C=0.01, svm__gamma=0.03555161734461004, svm__kernel=rbf; total time=   0.6s
# [CV] END svm__C=1.8784481701579407, svm__gamma=0.06502241815570407, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=10.0, svm__gamma=0.03383318141768203, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=10.0, svm__gamma=0.030635322695856965, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=2.186103816214272, svm__gamma=0.02313280792398825, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=5.825409774417774, svm__gamma=0.016342340085658904, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=9.620480216782168, svm__gamma=0.06605708874356064, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=0.0686933348396808, svm__degree=2, svm__gamma=0.028313355701429222, svm__kernel=poly; total time=   0.3s
# [CV] END svm__C=0.2160217783087772, svm__gamma=5.703843027403095, svm__kernel=rbf; total time=   1.9s
# [CV] END svm__C=0.7099668574083867, svm__gamma=2.1188154764215272, svm__kernel=rbf; total time=   1.9s
# [CV] END svm__C=4.339179954777639, svm__gamma=0.11897194666009088, svm__kernel=rbf; total time=   0.7s
# [CV] END ......svm__C=10.0, svm__gamma=0.01, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=2.2721159631496177, svm__gamma=0.01, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=10.0, svm__gamma=0.02060715284506024, svm__kernel=rbf; total time=   0.5s
# [CV] END svm__C=0.6864724267283363, svm__gamma=0.05152867693661163, svm__kernel=rbf; total time=   0.5s
# [CV] END svm__C=10.0, svm__gamma=0.028928901369469892, svm__kernel=rbf; total time=   0.5s
# [CV] END svm__C=5.904447153489793, svm__gamma=0.03647756285717963, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=10.0, svm__gamma=0.03730830878501653, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=0.1685452103986022, svm__degree=4, svm__gamma=1.4796158591210182, svm__kernel=poly; total time=  35.4s
# [CV] END svm__C=2.7364528220782454, svm__gamma=0.032780432870046915, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=0.42678505501429925, svm__gamma=5.754766135782297, svm__kernel=rbf; total time=   2.1s
# [CV] END ......svm__C=0.01, svm__gamma=0.01, svm__kernel=rbf; total time=   0.6s
# [CV] END svm__C=0.6860853777761778, svm__gamma=0.11810435058893747, svm__kernel=rbf; total time=   0.6s
# [CV] END svm__C=1.5537411198532722, svm__gamma=0.12629667201466538, svm__kernel=rbf; total time=   0.5s
# [CV] END svm__C=10.0, svm__gamma=0.04828339480851299, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=6.189762574450891, svm__gamma=0.0337815589786351, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=4.471753486934631, svm__gamma=0.051675383408881184, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=10.0, svm__gamma=0.028976369443544574, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=1.409382989699629, svm__gamma=0.08410886518204938, svm__kernel=rbf; total time=   0.4s
# [CV] END svm__C=1.3275617813445113, svm__degree=2, svm__gamma=0.05909339459694243, svm__kernel=poly; total time=   0.3s

# %%
# # parameter search using GridSearchCV

# # manually create the grid:
# c1 = np.arange(0.01 , 0.1 , 0.02)
# c2 = np.arange(0.1 , 1 , 0.2)
# c3 = np.arange(1 , 10 , 2)
# c_options = np.concatenate((c1, c2, c3))
# gamma_options = c_options
# degree_options = [2,3,4,5]
# kernel_option = ["rbf" , "poly"]

# param_grid = [
#     {
#         "svm__kernel": [kernel_option[0]],
#         "svm__C": c_options,                
#         "svm__gamma": gamma_options, 
#     },
#     {
#         "svm__kernel": [kernel_option[1]],
#         "svm__C": c_options,
#         "svm__gamma": gamma_options,
#         "svm__degree": degree_options,
#     }
# ]

# grid = GridSearchCV(
#     estimator=pipeline,
#     param_grid=param_grid,
#     scoring="matthews_corrcoef",   
#     n_jobs=-1,
#     refit=False,                 
#     verbose=3,
#     cv=cv
# )

# grid.fit(x_all, y_all)
# print("\n[Best parameters found:] ")
# print(grid.best_params_)
# print(f"[Best MCC validation] {grid.best_score_:.4f}")

# %%
#predict the benchmark set
pipeline.set_params(svm__C=best_params__{'svm__C'}, svm__gamma=best_params_{'svm__gamma'} ,svm__kernel=best_params_{'svm_kernel'}).fit(x_training_conc, y_training_conc) #parameters of GridSearchCV
bench_pred = pipeline.predict(x_benchmark)
#compute the mcc
mcc_grid = matthews_corrcoef(target_benchmark_vector , bench_pred)
print(f"MCC on testing set (grid search): {mcc_grid}")

pipeline.set_params(svm__C=10, svm__gamma=0.029917234770138655 ,svm__kernel="rbf").fit(x_training_conc, y_training_conc) #parameters of BayesSearchCV
bench_pred = pipeline.predict(x_benchmark)
#compute the mcc
mcc_bayes = matthews_corrcoef(target_benchmark_vector , bench_pred)
print(f"MCC on testing set (bayesian search): {mcc_bayes}")

# %% [markdown]
# BayesianSearchCV and GridSearchCV converged on practically the same parameters, that yield almost equal results

# %%
conf_mat = confusion_matrix(target_benchmark_vector , bench_pred)
sns.heatmap(
        conf_mat,
        annot=True,
        cmap="Blues",
        fmt="d",
        cbar=False,
        vmax = 200      
    )
plt.xlabel("Predicted")
plt.ylabel("Observed")  
plt.title("Confusion Matrix")  
plt.xticks(ticks=[0.5, 1.5], labels=["Negative", "Positive"])
plt.yticks(ticks=[0.5, 1.5], labels=["Negative", "Positive"], rotation=0)
