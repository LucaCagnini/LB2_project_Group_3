# %%
! pip install import-ipynb
# Out:
# Requirement already satisfied: import-ipynb in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (0.2)
# Requirement already satisfied: IPython in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from import-ipynb) (9.2.0)
# Requirement already satisfied: nbformat in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from import-ipynb) (5.10.4)
# Requirement already satisfied: decorator in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from IPython->import-ipynb) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from IPython->import-ipynb) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from IPython->import-ipynb) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from IPython->import-ipynb) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from IPython->import-ipynb) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from IPython->import-ipynb) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from IPython->import-ipynb) (2.19.1)
# Requirement already satisfied: stack_data in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from IPython->import-ipynb) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from IPython->import-ipynb) (5.14.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from nbformat->import-ipynb) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from nbformat->import-ipynb) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from nbformat->import-ipynb) (5.7.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->import-ipynb) (4.3.8)
# Requirement already satisfied: ptyprocess>=0.5 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython->import-ipynb) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from stack_data->IPython->import-ipynb) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from stack_data->IPython->import-ipynb) (3.0.0)
# Requirement already satisfied: pure-eval in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from stack_data->IPython->import-ipynb) (0.2.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in /home/mc02/ENTER/envs/lab1/lib/python3.12/site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->import-ipynb) (4.13.2)

# %%
import pandas as pd
import import_ipynb
from create_pswm import get_pswm
import math

# %%
def validation_testing(matrix , df , index): #index è il numero del training set da prendere come validation
    df_val = df.query("Set == @index") #take only validation sequences

    # iterate among all sequences in the validation set. 

    validation_scores = [] #list that contains all the scores of the sequences
    
    for _ , row in df_val.iterrows():
        
        seq = row["Sequence"] #extract the sequence from the dataframe
        pos = 0 # counter for window size tracking
        aa = 0 # index that moves along the sequence
        tmp_score = 0 #inizialise window score
        max_window_score = -math.inf , 0 , 0 , "seq" # initialize a variable that keeps in memory only the best window 
        
        end = min(90, len(seq)) # we end iterating on the sequence when we reach the 90th aa or when the sequence ends (sequence length < 90 aa)
        
        while aa < end - 14: # iteration on the sequence
            while pos <= 14: # iteration while the window is less than the fixed window size
                tmp_score += matrix[seq[aa + pos]][pos] # computing the score of the window
                pos +=1 # increasing the window size counter

            if tmp_score > max_window_score[0]: # checking if the actual window has a better score than the previous one
                max_window_score = tmp_score, aa, aa + pos, seq[aa:aa + pos]

            aa += 1 # increase the starting point
            pos = 0 # resetting the window size
                
        
        validation_scores.append(max_window_score) #da trasformare in dataframe usando corrispondenza indici lista con indici df_val con sequenze

    return validation_scores

# %%
if __name__ == "__main__":
    df=pd.read_csv("../Data_Preparation/train_bench.tsv", sep="\t")
    df_pos=df.query("Class=='Positive' and (Set=='1' or Set=='2' or Set=='3' or Set=='4' or Set=='5')").reset_index()
    for index,row in df_pos.iterrows():
            sequence_to_recover=row["Sequence"]
            cleavage_position=int(row["SPEnd"])
            df_pos.loc[index, "Sequence"] = sequence_to_recover[cleavage_position-13:cleavage_position+2]

    matrix = get_pswm(df_pos)
    print(validation_testing(matrix, df, "1"))
# Out:
