# %%
! pip install import-ipynb
! pip install scikit-learn
# Out:
# Requirement already satisfied: import-ipynb in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (0.2)
# Requirement already satisfied: IPython in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from import-ipynb) (9.1.0)
# Requirement already satisfied: nbformat in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from import-ipynb) (5.10.4)
# Requirement already satisfied: decorator in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from IPython->import-ipynb) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from IPython->import-ipynb) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from IPython->import-ipynb) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from IPython->import-ipynb) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from IPython->import-ipynb) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from IPython->import-ipynb) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from IPython->import-ipynb) (2.19.1)
# Requirement already satisfied: stack_data in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from IPython->import-ipynb) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from IPython->import-ipynb) (5.14.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from nbformat->import-ipynb) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from nbformat->import-ipynb) (4.25.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from nbformat->import-ipynb) (5.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->import-ipynb) (4.3.7)
# Requirement already satisfied: ptyprocess>=0.5 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython->import-ipynb) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from stack_data->IPython->import-ipynb) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from stack_data->IPython->import-ipynb) (3.0.0)
# Requirement already satisfied: pure_eval in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from stack_data->IPython->import-ipynb) (0.2.3)
# Requirement already satisfied: scikit-learn in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from scikit-learn) (2.2.5)
# Requirement already satisfied: scipy>=1.8.0 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/markus/anaconda3/envs/lab1/lib/python3.13/site-packages (from scikit-learn) (3.6.0)

# %%
import pandas as pd
import import_ipynb
from create_pswm import get_pswm
import math
import numpy as np
import seaborn as sns
import sklearn.metrics as skl
from sklearn.metrics import precision_recall_curve

# %%
def algorithm_vonheijne(matrix , df_val): 
    
    # iterate among all sequences in the validation set. 
    
    validation_complete = [] #list that contains all the scores as well as additional informations
    validation_scores = [] #list that only contains the scores
    
    for _ , row in df_val.iterrows():

        seq = row["Sequence"] #extract the sequence from the dataframe
        pos = 0 # counter for window size tracking
        aa = 0 # index that moves along the sequence
        tmp_score = 0 #inizialise window score
        max_window_score = -math.inf , 0 , 0 , "seq" # initialize a variable that keeps in memory only the best window 
        
        end = min(90, len(seq)) # we end iterating on the sequence when we reach the 90th aa or when the sequence ends (sequence length < 90 aa)
        
        while aa < end - 14: # iteration on the sequence
            while pos <= 14: # iteration while the window is less than the fixed window size
                try: #try statement to handle aminoacids not found in the matrix
                    tmp_score += matrix[seq[aa + pos]][pos] # computing the score of the window
                except KeyError :
                    tmp_score += 0
                pos +=1 # increasing the window size counter
            if tmp_score > max_window_score[0]: # checking if the actual window has a better score than the previous one
                max_window_score = tmp_score, aa, aa + pos, seq[aa:aa + pos]
                
            aa += 1 # increase the starting point
            pos = 0 # resetting the window size

        validation_scores.append(max_window_score[0])
        validation_complete.append(max_window_score) 
    return validation_complete , validation_scores

# %%
def class_vector(df_obs): #function that creates a class vector for all the sequences in a dataset given the index
    class_list = []
    for _ , row in df_obs.iterrows():
        if row["Class"] == "Negative":
            class_list.append(0)
        else: #if row["Class"] == "Positive"
            class_list.append(1)
    return class_list

# %%
def best_threshold(validation_class , validation_scores , test_class , test_scores ): #secondo te cosa fa una funzione che si chiama best threshold? 

    # index --> index of the test set
    # validation_class --> classes observed in the validation set
    # validation_scores --> scores computed on the validation set

    #best_treshold --> best threshold according to the validation set
    
    # test_scores --> scores computed on the test set
    # test_class --> classes observed in the test set
    
    
    precision, recall, thresholds = precision_recall_curve(validation_class, validation_scores)
    if precision + recall == 0: 
        f_score = 0.
    else: 
        f_score = (2*precision*recall) / (precision+recall)
    index_th = np.argmax(f_score)
    best_threshold = thresholds[index_th]
    predicted_class = [int( score >= best_threshold) for score in test_scores]

    #return the list that contains the predicted classes of the test_set
    return predicted_class, precision, recall
# Out:
#   Cell In[5], line 15
#     f-score = 0.0
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
def metrics(pswm, validation, test):

    obs_validation = class_vector(validation)
    val_scores , val_scores_only = algorithm_vonheijne(pswm, validation)  #validation scores and binary classification
    obs_test = class_vector(test)
    test_scores, test_scores_only = algorithm_vonheijne(pswm, test)   #test scores and binary classification
    predicted_class_test, precision, recall = best_threshold(obs_validation, val_scores_only, obs_test, test_scores_only)

    MCC = skl.matthews_corrcoef(obs_test, predicted_class_test)            # Matthews Correlation Coefficient
    ACC = skl.accuracy_score(obs_test, predicted_class_test)               # Accuracy
    PPV = skl.precision_score(obs_test, predicted_class_test)              # Precision
    SEN = skl.classification_report(obs_test, predicted_class_test)        # Recall

    return MCC, ACC, PPV, SEN

# %%
# TEST CELL : validation_scores function
if __name__ == "__main__":
    df=pd.read_csv("../Data_Preparation/train_bench.tsv", sep="\t")
    df_pos=df.query("Class=='Positive' and (Set=='1' or Set=='2' or Set=='3' or Set=='4' or Set=='5')")

    matrix = get_pswm(df_pos,13,2)
    a , b = validation_scores(matrix, df, "3")
    #print(a)
   #print(b)

# %%
# TEST CELL : class_vector function
if __name__ == "__main__":
    print('cacca')
    
    # GRAFICO DA SISTEMARE PERCHè FA SCHIFO !!!!
