# %% [markdown]
# # loop the indexes to run the cross validation in such a way that one set is the validaion, one set is the test and the remaining tre are the training ones.

# %%
! pip install import-ipynb
# %run create_pswm.ipynb
import import_ipynb
import create_pswm
get_pswm = create_pswm.get_pswm
import pandas as pd
 
total = pd.read_csv("../Data_Preparation/train_bench.tsv", sep = "\t")
for i in range(1,6):
    tupla=((((i+1)%5)+1),(((i+2)%5)+1),(((i+3)%5)+1))
    testing = total.query(f"Set=='{i}'")
    validation = total.query(f"Set=='{(i)%5}'")
    training=total.query(f"Set=='{tupla[0]}' or Set=='{tupla[1]}' or Set=='{tupla[2]}'")
    print("testing set: ",i)
    print("validation set: ", ((i)%5)+1)
    print("training sets: ",tupla, "\n")
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/nbformat/__init__.py:169, in read(fp, as_version, capture_validation_error, **kwargs)
#     168 try:
# --> 169     buf = fp.read()
#     170 except AttributeError:
#
# AttributeError: 'PosixPath' object has no attribute 'read'
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/nbformat/reader.py:19, in parse_json(s, **kwargs)
#      18 try:
# ---> 19     nb_dict = json.loads(s, **kwargs)
#      20 except ValueError as e:
#
# File /opt/anaconda3/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
# ...
